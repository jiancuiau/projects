# %%
import keras
import numpy as np
import matplotlib.pyplot as plt

from keras.models import Sequential
from keras.layers import Dense

# %%
x_data = np.random.rand(100)
noise = np.random.normal(0,0.01,x_data.shape)
y_data = x_data*0.1+0.2+noise

plt.scatter(x_data,y_data)

# %%
model = Sequential()

model.add(Dense(units = 1,input_dim =1))
#sgd stochastic gradient descent
#mse mean squared error
model.compile(optimizer = "sgd",loss = 'mse')

for step in range(3001):
    cost = model.train_on_batch(x_data,y_data)
    if step % 500 == 0:
        print("cost:",cost)
# get weights   
h = model.layers[0].get_weights()
print(h)
W, b = model.layers[0].get_weights()
print('W:',W,'b:',b)
#
y_pred = model.predict(x_data)

plt.scatter(x_data,y_data)

plt.plot(x_data,y_pred,'r-',lw =3)
plt.show()
# Out:
# cost: 0.14375586807727814
# cost: 0.0006634765304625034
# cost: 0.0002244091738248244
# cost: 0.00012554175918921828
# cost: 0.00010327918425900862
# cost: 9.826615132624283e-05
# cost: 9.713736653793603e-05
# [array([[0.09827906]], dtype=float32), array([0.20120412], dtype=float32)]
# W: [[0.09827906]] b: [0.20120412]

# %%
# non linear model

import keras
import numpy as np
import matplotlib.pyplot as plt

from keras.models import Sequential
from keras.layers import Dense,Activation
#from keras.optimizers import SGD
import tensorflow as tf
from tensorflow.keras.optimizers import SGD

# %%
x = np.linspace(-0.5,0.5,200)
noise = np.random.normal(0,0.02,x.shape)
y = np.square(x)+noise

plt.scatter(x,y)
plt.show()

# %%
model = Sequential()
#############################################
model.add(Dense(units = 1,input_dim =1))
#############################################

#sgd stochastic gradient descent
#mse mean squared error
model.compile(optimizer = "sgd",loss = 'mse')

for step in range(3001):
    cost = model.train_on_batch(x,y)
    if step % 500 == 0:
        print("cost:",cost)
# get weights   
h = model.layers[0].get_weights()
print(h)
W, b = model.layers[0].get_weights()
print('W:',W,'b:',b)
#
y_pred = model.predict(x)

plt.scatter(x,y)

plt.plot(x,y_pred,'r-',lw =3)
plt.show()
# Out:
# cost: 0.029559873044490814
# cost: 0.00881955586373806
# cost: 0.006349623203277588
# cost: 0.005891512613743544
# cost: 0.005806544795632362
# cost: 0.0057907854206860065
# cost: 0.005787862464785576
# [array([[0.0023452]], dtype=float32), array([0.0861598], dtype=float32)]
# W: [[0.0023452]] b: [0.0861598]

# %%
model = Sequential()
#############################################
#model.add(Dense(units = 10,input_dim =1))
#model.add(Activation('tanh'))
#model.add(Dense(units = 1))
#model.add(Activation('tanh'))
#############################################
model.add(Dense(units = 10,activation = 'relu',input_dim =1))
model.add(Dense(units = 1,activation = 'relu'))
#############################################
sgd = SGD(learning_rate = 0.3)
#sgd stochastic gradient descent
#mse mean squared error
model.compile(optimizer = sgd,loss = 'mse')



for step in range(3001):
    cost = model.train_on_batch(x,y)
    if step % 500 == 0:
        print("cost:",cost)
# get weights   
h = model.layers[0].get_weights()
print(h)

y_pred = model.predict(x)

plt.scatter(x,y)

plt.plot(x,y_pred,'r-',lw =3)
plt.show()
# Out:
# cost: 0.009357595816254616
# cost: 0.0005330268177203834
# cost: 0.0004965331172570586
# cost: 0.0004929230199195445
# cost: 0.000492395251058042
# cost: 0.0004923598608002067
# cost: 0.000492357590701431
# [array([[ 0.05361333,  0.52314955, -0.3846873 ,  0.34809828, -0.5825562 ,
#         -0.17329623, -0.55844814, -0.82216996, -0.80162436, -0.7060134 ]],
#       dtype=float32), array([-0.02689753,  0.01741011,  0.19235602, -0.17407247,  0.00055003,
#         0.0866649 ,  0.04005015,  0.001777  ,  0.00289182,  0.00210932],
#       dtype=float32)]

# %%
###############################################
##############333333333333333##################
###############################################

# %%
import numpy as np
import pandas
from keras.datasets import mnist
from keras.utils import np_utils
from keras.models import Sequential
from keras.layers import Dense
#from keras.optimizers import SGD
import tensorflow as tf
from tensorflow.keras.optimizers import SGD

# %%
(x_train,y_train),(x_test,y_test)= mnist.load_data()

print('x_shape:',x_train.shape)
print('y_shape:',y_train.shape)
x_train = x_train.reshape(x_train.shape[0],-1)/255.0
x_test = x_test.reshape(x_test.shape[0],-1)/255.0
# to one hot format

y_train = np_utils.to_categorical(y_train,num_classes =10)
y_test = np_utils.to_categorical(y_test,num_classes =10)

model = Sequential([Dense(units = 10, input_dim= 784,bias_initializer = 'one', activation = 'softmax')])

sgd = SGD(learning_rate = 0.2)

model.compile(optimizer = sgd,loss = 'mse',metrics = ['accuracy'])

model.fit(x_train,y_train,batch_size = 32,epochs = 10)

loss, accuracy = model.evaluate(x_test,y_test)

print('\ntest loss', loss)
print('accuracy',accuracy)
# Out:
# x_shape: (60000, 28, 28)
# y_shape: (60000,)
# Epoch 1/10
# 1875/1875 [==============================] - 2s 745us/step - loss: 0.0375 - accuracy: 0.7755
# Epoch 2/10
# 1875/1875 [==============================] - 1s 605us/step - loss: 0.0204 - accuracy: 0.8796
# Epoch 3/10
# 1875/1875 [==============================] - 1s 571us/step - loss: 0.0178 - accuracy: 0.8924
# Epoch 4/10
# 1875/1875 [==============================] - 1s 567us/step - loss: 0.0165 - accuracy: 0.8987
# Epoch 5/10
# 1875/1875 [==============================] - 1s 591us/step - loss: 0.0157 - accuracy: 0.9027
# Epoch 6/10
# 1875/1875 [==============================] - 1s 585us/step - loss: 0.0151 - accuracy: 0.9060
# Epoch 7/10
# 1875/1875 [==============================] - 1s 556us/step - loss: 0.0147 - accuracy: 0.9086
# Epoch 8/10
# 1875/1875 [==============================] - 1s 558us/step - loss: 0.0143 - accuracy: 0.9109
# Epoch 9/10
# 1875/1875 [==============================] - 1s 573us/step - loss: 0.0140 - accuracy: 0.9123
# Epoch 10/10
# 1875/1875 [==============================] - 1s 559us/step - loss: 0.0138 - accuracy: 0.9133
# 313/313 [==============================] - 0s 508us/step - loss: 0.0131 - accuracy: 0.9176
#
# test loss 0.013102879747748375
# accuracy 0.9175999760627747

# %%
###############################################
##############444444444444444##################
###############################################

# %%
(x_train,y_train),(x_test,y_test)= mnist.load_data()

print('x_shape:',x_train.shape)
print('y_shape:',y_train.shape)
x_train = x_train.reshape(x_train.shape[0],-1)/255.0
x_test = x_test.reshape(x_test.shape[0],-1)/255.0
# to one hot format

y_train = np_utils.to_categorical(y_train,num_classes =10)
y_test = np_utils.to_categorical(y_test,num_classes =10)

model = Sequential([Dense(units = 10, input_dim= 784,bias_initializer = 'one', activation = 'softmax')])

sgd = SGD(learning_rate = 0.2)

model.compile(optimizer = sgd,loss = 'categorical_crossentropy',metrics = ['accuracy'])

model.fit(x_train,y_train,batch_size = 32,epochs = 10)

loss, accuracy = model.evaluate(x_test,y_test)

print('\ntest loss', loss)
print('accuracy',accuracy)
# Out:
# x_shape: (60000, 28, 28)
# y_shape: (60000,)
# Epoch 1/10
# 1875/1875 [==============================] - 1s 636us/step - loss: 0.3781 - accuracy: 0.8929
# Epoch 2/10
# 1875/1875 [==============================] - 1s 612us/step - loss: 0.3024 - accuracy: 0.9139
# Epoch 3/10
# 1875/1875 [==============================] - 1s 632us/step - loss: 0.2890 - accuracy: 0.9182
# Epoch 4/10
# 1875/1875 [==============================] - 1s 621us/step - loss: 0.2826 - accuracy: 0.9208
# Epoch 5/10
# 1875/1875 [==============================] - 1s 703us/step - loss: 0.2782 - accuracy: 0.9222
# Epoch 6/10
# 1875/1875 [==============================] - 1s 615us/step - loss: 0.2748 - accuracy: 0.9234
# Epoch 7/10
# 1875/1875 [==============================] - 1s 616us/step - loss: 0.2727 - accuracy: 0.9238
# Epoch 8/10
# 1875/1875 [==============================] - 1s 624us/step - loss: 0.2686 - accuracy: 0.92510s - loss: 0.2661 - accu
# Epoch 9/10
# 1875/1875 [==============================] - 2s 828us/step - loss: 0.2670 - accuracy: 0.9259
# Epoch 10/10
# 1875/1875 [==============================] - 1s 683us/step - loss: 0.2659 - accuracy: 0.9265
# 313/313 [==============================] - 0s 627us/step - loss: 0.2750 - accuracy: 0.9232
#
# test loss 0.27501124143600464
# accuracy 0.9232000112533569

# %%
###############################################
##############555555555555555##################
###############################################


## dorpout for preventing overfitting

# %%
import numpy as np
import pandas
from keras.datasets import mnist
from keras.utils import np_utils
from keras.models import Sequential
from keras.layers import Dense,Dropout
#from keras.optimizers import SGD
import tensorflow as tf
from tensorflow.keras.optimizers import SGD
(x_train,y_train),(x_test,y_test)= mnist.load_data()

print('x_shape:',x_train.shape)
print('y_shape:',y_train.shape)
x_train = x_train.reshape(x_train.shape[0],-1)/255.0
x_test = x_test.reshape(x_test.shape[0],-1)/255.0
# to one hot format

y_train = np_utils.to_categorical(y_train,num_classes =10)
y_test = np_utils.to_categorical(y_test,num_classes =10)

model = Sequential([Dense(units = 200, input_dim= 784,bias_initializer = 'one', activation = 'tanh'),
                    Dropout(0.4),
                   Dense(units = 100, bias_initializer = 'one', activation = 'tanh'),
                    Dropout(0.4),
                    Dense(units = 10,bias_initializer = 'one', activation = 'softmax')
                   ]
                  )

sgd = SGD(learning_rate = 0.2)

model.compile(optimizer = sgd,loss = 'categorical_crossentropy',metrics = ['accuracy'])

model.fit(x_train,y_train,batch_size = 32,epochs = 10)

loss, accuracy = model.evaluate(x_test,y_test)

print('\ntest loss', loss)
print('accuracy',accuracy)
loss, accuracy = model.evaluate(x_train,y_train)

print('Train \ntest loss', loss)
print('Trian accuracy',accuracy)
# Out:
# x_shape: (60000, 28, 28)
# y_shape: (60000,)
# Epoch 1/10
# 1875/1875 [==============================] - 3s 1ms/step - loss: 0.4466 - accuracy: 0.8640
# Epoch 2/10
# 1875/1875 [==============================] - 2s 1ms/step - loss: 0.2843 - accuracy: 0.9147
# Epoch 3/10
# 1875/1875 [==============================] - 2s 1ms/step - loss: 0.2438 - accuracy: 0.9278
# Epoch 4/10
# 1875/1875 [==============================] - 2s 1ms/step - loss: 0.2157 - accuracy: 0.9357
# Epoch 5/10
# 1875/1875 [==============================] - 3s 1ms/step - loss: 0.2037 - accuracy: 0.9393
# Epoch 6/10
# 1875/1875 [==============================] - 3s 1ms/step - loss: 0.1860 - accuracy: 0.9445
# Epoch 7/10
# 1875/1875 [==============================] - 2s 1ms/step - loss: 0.1776 - accuracy: 0.9471
# Epoch 8/10
# 1875/1875 [==============================] - 2s 1ms/step - loss: 0.1684 - accuracy: 0.9495: 1s - loss: 0.1
# Epoch 9/10
# 1875/1875 [==============================] - 2s 1ms/step - loss: 0.1634 - accuracy: 0.9515
# Epoch 10/10
# 1875/1875 [==============================] - 3s 1ms/step - loss: 0.1544 - accuracy: 0.9535
# 313/313 [==============================] - 0s 908us/step - loss: 0.0977 - accuracy: 0.9710
#
# test loss 0.09767328947782516
# accuracy 0.9710000157356262
# 1875/1875 [==============================] - 3s 1ms/step - loss: 0.0684 - accuracy: 0.9791
# Train
# test loss 0.06842349469661713
# Trian accuracy 0.9790666699409485

# %%
###############################################
##############666666666666666##################
###############################################

import numpy as np
import pandas
from keras.datasets import mnist
from keras.utils import np_utils
from keras.models import Sequential
from keras.layers import Dense
#from keras.optimizers import SGD
import tensorflow as tf
from tensorflow.keras.optimizers import SGD
from keras.regularizers import l2

# %%
(x_train,y_train),(x_test,y_test)= mnist.load_data()

print('x_shape:',x_train.shape)
print('y_shape:',y_train.shape)
x_train = x_train.reshape(x_train.shape[0],-1)/255.0
x_test = x_test.reshape(x_test.shape[0],-1)/255.0
# to one hot format

y_train = np_utils.to_categorical(y_train,num_classes =10)
y_test = np_utils.to_categorical(y_test,num_classes =10)

model = Sequential([Dense(units = 200, input_dim= 784,bias_initializer = 'one', activation = 'tanh',kernel_regularizer = l2(0.0003)),
                    
                   Dense(units = 100, bias_initializer = 'one', activation = 'tanh',kernel_regularizer = l2(0.0003)),
                    
                    Dense(units = 10,bias_initializer = 'one', activation = 'softmax',kernel_regularizer = l2(0.0003))
                   ]
                  )

sgd = SGD(learning_rate = 0.2)

model.compile(optimizer = sgd,loss = 'categorical_crossentropy',metrics = ['accuracy'])

model.fit(x_train,y_train,batch_size = 32,epochs = 10)

loss, accuracy = model.evaluate(x_test,y_test)

print('\ntest loss', loss)
print('accuracy',accuracy)
loss, accuracy = model.evaluate(x_train,y_train)

print('Train \ntest loss', loss)
print('Trian accuracy',accuracy)
# Out:
# x_shape: (60000, 28, 28)
# y_shape: (60000,)
# Epoch 1/10
# 1875/1875 [==============================] - 3s 1ms/step - loss: 0.4324 - accuracy: 0.9133
# Epoch 2/10
# 1875/1875 [==============================] - 3s 1ms/step - loss: 0.2634 - accuracy: 0.9600
# Epoch 3/10
# 1875/1875 [==============================] - 3s 2ms/step - loss: 0.2200 - accuracy: 0.9685
# Epoch 4/10
# 1875/1875 [==============================] - 3s 1ms/step - loss: 0.1944 - accuracy: 0.9738
# Epoch 5/10
# 1875/1875 [==============================] - 3s 1ms/step - loss: 0.1788 - accuracy: 0.9762
# Epoch 6/10
# 1875/1875 [==============================] - 3s 1ms/step - loss: 0.1710 - accuracy: 0.9773
# Epoch 7/10
# 1875/1875 [==============================] - 3s 1ms/step - loss: 0.1628 - accuracy: 0.9790
# Epoch 8/10
# 1875/1875 [==============================] - 3s 2ms/step - loss: 0.1583 - accuracy: 0.9791: 0s - loss: 0.1584 - ac
# Epoch 9/10
# 1875/1875 [==============================] - 3s 1ms/step - loss: 0.1539 - accuracy: 0.9807
# Epoch 10/10
# 1875/1875 [==============================] - 3s 1ms/step - loss: 0.1509 - accuracy: 0.9812
# 313/313 [==============================] - 0s 936us/step - loss: 0.1827 - accuracy: 0.9705
#
# test loss 0.18266677856445312
# accuracy 0.9704999923706055
# 1875/1875 [==============================] - 2s 1ms/step - loss: 0.1590 - accuracy: 0.9785
# Train
# test loss 0.15901485085487366
# Trian accuracy 0.9785333275794983

# %%
###############################################
##############777777777777777##################
###############################################

import numpy as np
import pandas
from keras.datasets import mnist
from keras.utils import np_utils
from keras.models import Sequential
from keras.layers import Dense
#from keras.optimizers import SGD
import tensorflow as tf
from tensorflow.keras.optimizers import SGD,Adam
from keras.regularizers import l2

# %%
(x_train,y_train),(x_test,y_test)= mnist.load_data()

print('x_shape:',x_train.shape)
print('y_shape:',y_train.shape)
x_train = x_train.reshape(x_train.shape[0],-1)/255.0
x_test = x_test.reshape(x_test.shape[0],-1)/255.0
# to one hot format

y_train = np_utils.to_categorical(y_train,num_classes =10)
y_test = np_utils.to_categorical(y_test,num_classes =10)

model = Sequential([Dense(units = 10, input_dim= 784,bias_initializer = 'one', activation = 'softmax'),
                    
                   ]
                  )

sgd = SGD(learning_rate = 0.2)
adam = Adam(learning_rate = 0.001)

model.compile(optimizer = adam,loss = 'categorical_crossentropy',metrics = ['accuracy'])

model.fit(x_train,y_train,batch_size = 32,epochs = 10)

loss, accuracy = model.evaluate(x_test,y_test)

print('\ntest loss', loss)
print('accuracy',accuracy)
loss, accuracy = model.evaluate(x_train,y_train)

print('Train \ntest loss', loss)
print('Trian accuracy',accuracy)
# Out:
# x_shape: (60000, 28, 28)
# y_shape: (60000,)
# Epoch 1/10
# 1875/1875 [==============================] - 1s 623us/step - loss: 0.4674 - accuracy: 0.8782
# Epoch 2/10
# 1875/1875 [==============================] - 1s 608us/step - loss: 0.3038 - accuracy: 0.9154
# Epoch 3/10
# 1875/1875 [==============================] - 1s 689us/step - loss: 0.2837 - accuracy: 0.9208
# Epoch 4/10
# 1875/1875 [==============================] - 1s 642us/step - loss: 0.2735 - accuracy: 0.9229
# Epoch 5/10
# 1875/1875 [==============================] - 1s 619us/step - loss: 0.2669 - accuracy: 0.9256
# Epoch 6/10
# 1875/1875 [==============================] - 1s 663us/step - loss: 0.2618 - accuracy: 0.9271
# Epoch 7/10
# 1875/1875 [==============================] - 1s 634us/step - loss: 0.2584 - accuracy: 0.9281
# Epoch 8/10
# 1875/1875 [==============================] - 2s 835us/step - loss: 0.2555 - accuracy: 0.9296
# Epoch 9/10
# 1875/1875 [==============================] - 1s 733us/step - loss: 0.2530 - accuracy: 0.9301
# Epoch 10/10
# 1875/1875 [==============================] - 2s 866us/step - loss: 0.2512 - accuracy: 0.9303
# 313/313 [==============================] - 0s 589us/step - loss: 0.2675 - accuracy: 0.9263
#
# test loss 0.26753589510917664
# accuracy 0.9262999892234802
# 1875/1875 [==============================] - 2s 800us/step - loss: 0.2469 - accuracy: 0.9320
# Train
# test loss 0.24692212045192719
# Trian accuracy 0.9320166707038879

# %%
###############################################
##############888888888888888##################
###############################################

import numpy as np
import pandas
from keras.datasets import mnist
from keras.utils import np_utils
from keras.models import Sequential
from keras.layers import Dense,Dropout,Convolution2D,MaxPooling2D,Flatten
#from keras.optimizers import SGD
import tensorflow as tf
from tensorflow.keras.optimizers import SGD,Adam
from keras.regularizers import l2

# %%
(x_train,y_train),(x_test,y_test)= mnist.load_data()

print('x_shape:',x_train.shape)
print('y_shape:',y_train.shape)
x_train = x_train.reshape(-1,28,28,1)/255.0
x_test = x_test.reshape(-1,28,28,1)/255.0
# to one hot format

y_train = np_utils.to_categorical(y_train,num_classes =10)
y_test = np_utils.to_categorical(y_test,num_classes =10)

model = Sequential()
#####
model.add(Convolution2D(input_shape = (28,28,1),filters =32,kernel_size = 5 ,strides = 1,
                       padding = 'same',
                       activation = 'relu'))

model.add(MaxPooling2D(pool_size =2, strides = 2,padding ='same'))

######
model.add(Convolution2D(64,5,strides = 1,
                       padding = 'same',
                       activation = 'relu'))

model.add(MaxPooling2D(pool_size =2, strides = 2,padding ='same'))
######
model.add(Flatten())

model.add(Dense(1024,activation = 'relu'))

model.add(Dropout(0.5))

model.add(Dense(10,activation = 'softmax'))


adam = Adam(learning_rate = 0.0001)

model.compile(optimizer = adam,loss = 'categorical_crossentropy',metrics = ['accuracy'])

model.fit(x_train,y_train,batch_size = 32,epochs = 10)

loss, accuracy = model.evaluate(x_test,y_test)
# Out:
# x_shape: (60000, 28, 28)
# y_shape: (60000,)
# Epoch 1/10
# 1875/1875 [==============================] - 76s 40ms/step - loss: 0.2613 - accuracy: 0.9210
# Epoch 2/10
# 1875/1875 [==============================] - 86s 46ms/step - loss: 0.0748 - accuracy: 0.9771
# Epoch 3/10
# 1875/1875 [==============================] - 80s 43ms/step - loss: 0.0528 - accuracy: 0.9837
# Epoch 4/10
# 1875/1875 [==============================] - 96s 51ms/step - loss: 0.0414 - accuracy: 0.9869
# Epoch 5/10
# 1875/1875 [==============================] - 94s 50ms/step - loss: 0.0340 - accuracy: 0.9898
# Epoch 6/10
# 1875/1875 [==============================] - 89s 47ms/step - loss: 0.0281 - accuracy: 0.9913
# Epoch 7/10
# 1875/1875 [==============================] - 89s 48ms/step - loss: 0.0228 - accuracy: 0.9928
# Epoch 8/10
# 1875/1875 [==============================] - 86s 46ms/step - loss: 0.0205 - accuracy: 0.9934
# Epoch 9/10
# 1875/1875 [==============================] - 79s 42ms/step - loss: 0.0174 - accuracy: 0.9948
# Epoch 10/10
# 1875/1875 [==============================] - 92s 49ms/step - loss: 0.0151 - accuracy: 0.9954
# 313/313 [==============================] - 4s 11ms/step - loss: 0.0256 - accuracy: 0.9914
